# %%
import numpy as np
import pandas as pd
import re

# %%
data = pd.read_csv('/content/Tweets-2.csv')

# %%
data.head()
# Out:
#        tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  5.703060e+17           neutral                        1.0000
# 1  5.703010e+17          positive                        0.3486
# 2  5.703010e+17           neutral                        0.6837
# 3  5.703010e+17          negative                        1.0000
# 4  5.703010e+17          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
data.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %%
data = data.fillna("na")

# %%
data.isnull().sum()
# Out:
# tweet_id                        0
# airline_sentiment               0
# airline_sentiment_confidence    0
# negativereason                  0
# negativereason_confidence       0
# airline                         0
# airline_sentiment_gold          0
# name                            0
# negativereason_gold             0
# retweet_count                   0
# text                            0
# tweet_coord                     0
# tweet_created                   0
# tweet_location                  0
# user_timezone                   0
# dtype: int64

# %%
data['airline_sentiment'].unique()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['airline_sentiment'] = label_encoder.fit_transform(data['airline_sentiment'])

# %% [markdown]
# since there are three classes which are in categorical using label encoder these are converted into numerical. this is the target variable

# %%
data['airline_sentiment'].unique()
# Out:
# array([1, 2, 0])

# %% [markdown]
# there are a lot of null values hence these cannot be droppped this will be filled with na

# %%
data.head()
# Out:
#        tweet_id  airline_sentiment  airline_sentiment_confidence  \
# 0  5.703060e+17                  1                        1.0000
# 1  5.703010e+17                  2                        0.3486
# 2  5.703010e+17                  1                        0.6837
# 3  5.703010e+17                  0                        1.0000
# 4  5.703010e+17                  0                        1.0000
#
#   negativereason negativereason_confidence         airline  \
# 0             na                        na  Virgin America
# 1             na                       0.0  Virgin America
# 2             na                        na  Virgin America
# 3     Bad Flight                    0.7033  Virgin America
# 4     Can't Tell                       1.0  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                     na     cairdin                  na              0
# ...

# %%
import re
import string

# %%
data['text'] = data['text'].apply(lambda x: x.lower())
data['text'] = data['text'].apply(lambda x: re.sub(r'\W', ' ', x))

# %% [markdown]
# text preproccessing

# %%
data.head()
# Out:
#        tweet_id  airline_sentiment  airline_sentiment_confidence  \
# 0  5.703060e+17                  1                        1.0000
# 1  5.703010e+17                  2                        0.3486
# 2  5.703010e+17                  1                        0.6837
# 3  5.703010e+17                  0                        1.0000
# 4  5.703010e+17                  0                        1.0000
#
#   negativereason negativereason_confidence         airline  \
# 0             na                        na  Virgin America
# 1             na                       0.0  Virgin America
# 2             na                        na  Virgin America
# 3     Bad Flight                    0.7033  Virgin America
# 4     Can't Tell                       1.0  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                     na     cairdin                  na              0
# ...

# %%
text = data["text"]
labels = data["airline_sentiment"]

# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(text)
sequences = tokenizer.texts_to_sequences(text)

# %%
maxlen = 200
padded_sequences = pad_sequences(sequences, maxlen=maxlen)

# %% [markdown]
# here the text are tokenized and made into sequence for rnn and lstm

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# %%
def simple_rnn():
    model = Sequential()
    model.add(Embedding(input_dim=5000, output_dim=16, input_length=maxlen))
    model.add(SimpleRNN(32))
    model.add(Dense(3, activation="softmax"))
    model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    return model

# %% [markdown]
# sinse it is a multiclasss we will be using softmax activation function and sparse_categorical_crossentropy as loss function

# %%
rnnModel = simple_rnn()
history_rnn = rnnModel.fit(xtrain, ytrain, epochs=10, validation_data=(xtest, ytest))
# Out:
# Epoch 1/10
# 366/366 [==============================] - 20s 50ms/step - loss: 0.7681 - accuracy: 0.6729 - val_loss: 0.5998 - val_accuracy: 0.7568
# Epoch 2/10
# 366/366 [==============================] - 17s 45ms/step - loss: 0.5169 - accuracy: 0.7987 - val_loss: 0.5644 - val_accuracy: 0.7684
# Epoch 3/10
# 366/366 [==============================] - 16s 43ms/step - loss: 0.3585 - accuracy: 0.8712 - val_loss: 0.5622 - val_accuracy: 0.7814
# Epoch 4/10
# 366/366 [==============================] - 17s 47ms/step - loss: 0.3124 - accuracy: 0.8883 - val_loss: 0.5821 - val_accuracy: 0.7674
# Epoch 5/10
# 366/366 [==============================] - 16s 44ms/step - loss: 0.2842 - accuracy: 0.8943 - val_loss: 0.5853 - val_accuracy: 0.7708
# Epoch 6/10
# 366/366 [==============================] - 16s 44ms/step - loss: 0.1837 - accuracy: 0.9367 - val_loss: 0.7166 - val_accuracy: 0.7657
# Epoch 7/10
# ...

# %%
def lstm():
    model = Sequential()
    model.add(Embedding(input_dim=5000, output_dim=128, input_length=maxlen))
    model.add(LSTM(32))
    model.add(Dense(3, activation="softmax"))
    model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    return model

# %%
lstmModel = lstm()
history_lstm = lstmModel.fit(xtrain, ytrain, epochs=10, validation_data=(xtest, ytest))
# Out:
# Epoch 1/10
# 366/366 [==============================] - 39s 100ms/step - loss: 0.6512 - accuracy: 0.7333 - val_loss: 0.4941 - val_accuracy: 0.8009
# Epoch 2/10
# 366/366 [==============================] - 37s 100ms/step - loss: 0.4017 - accuracy: 0.8450 - val_loss: 0.5043 - val_accuracy: 0.8019
# Epoch 3/10
# 366/366 [==============================] - 37s 101ms/step - loss: 0.3042 - accuracy: 0.8855 - val_loss: 0.5468 - val_accuracy: 0.7927
# Epoch 4/10
# 366/366 [==============================] - 38s 104ms/step - loss: 0.2383 - accuracy: 0.9121 - val_loss: 0.5981 - val_accuracy: 0.8029
# Epoch 5/10
# 366/366 [==============================] - 45s 124ms/step - loss: 0.1871 - accuracy: 0.9352 - val_loss: 0.6668 - val_accuracy: 0.7896
# Epoch 6/10
# 366/366 [==============================] - 42s 114ms/step - loss: 0.1502 - accuracy: 0.9475 - val_loss: 0.7617 - val_accuracy: 0.7889
# Epoch 7/10
# ...

# %%
rnnL, rnnA = rnnModel.evaluate(xtest, ytest)
lstmL, lstmA = lstmModel.evaluate(xtest, ytest)

print("Accuracy RNN :", rnnA)
print("Accuracy LSTM:", lstmA)
# Out:
# ...
# 92/92 [==============================] - 3s 30ms/step - loss: 1.1264 - accuracy: 0.7722
# Accuracy RNN : 0.7424863576889038
# Accuracy LSTM: 0.7721994519233704

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
rnn_predictions = np.argmax(rnnModel.predict(xtest), axis=-1)
lstm_predictions = np.argmax(lstmModel.predict(xtest), axis=-1)

rnn_cm = confusion_matrix(ytest, rnn_predictions)
lstm_cm = confusion_matrix(ytest, lstm_predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(rnn_cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - RNN Model')
plt.show()

plt.figure(figsize=(8, 6))
sns.heatmap(lstm_cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - LSTM Model')
plt.show()
# Out:
# ...
# 92/92 [==============================] - 6s 61ms/step

# %%
plt.plot(history_rnn.history['accuracy'], label='RNN Training Accuracy')
plt.plot(history_rnn.history['val_accuracy'], label='RNN Validation Accuracy')
plt.title('RNN Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_lstm.history['accuracy'], label='LSTM Training Accuracy')
plt.plot(history_lstm.history['val_accuracy'], label='LSTM Validation Accuracy')
plt.title('LSTM Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
